# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Wed Dec 30 20:54:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
#  15961221826441930372638291359748.jpg
# '19BDA71034 (1).gdoc'
#  19BDA71034.gdoc
#  19BDA71034.gslides
#  1..gdoc
# '1st year FDS zip.zip'
#  2.aac
# '34 and 66.gslides'
#  797fa569-cec5-4a9e-ba7e-3950d3702e6b.zip
# '+91 99711 99566 20190611_164214.jpg'
#  A
#  AB.gslides
#  ABSTRACT.gdoc
# 'AI CARTOON - 19BDA71034.gdoc'
# 'AI CARTOON - 19BDA71034 - Line chart 1.gsheet'
# 'AI Cartoon.gdoc'
# 'Application for Certificate.gdoc'
#  bio.gdoc
# 'bioinfo(assignment3)19BDA71038.docx'
# 'bioinfo(assignment3)19BDA71038.gdoc'
# 'BIOINFORMATICS ASSIGNMENT .gdoc'
# 'BLAST - Hands on Assignment.gdoc'
# 'BRAND MANUAL-converted.gslides'
# 'BRAND MANUAL-converted.pptx'
# 'BRAND MANUAL.pdf'
#  Brochure.gdoc
# 'Calculator (1).aspx.cs.gdoc'
# 'Calculator (2).aspx.cs.gdoc'
#  Calculator.aspx.cs.gdoc
# ...

# %% [markdown]
# **1) Clone, configure & compile Darknet**

# %%
# Clone
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet/darknet

# %%
# Compile
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %% [markdown]
# **2) Configure yolov3.cfg file**

# %%
# Make a copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 10000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=9@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=9@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=9@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=42@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=42@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=42@' cfg/yolov3_training.cfg

# %% [markdown]
# **3) Create .names and .data files**

# %%
# !echo -e 'apple\nbanana\ncake\norange\nmilk' > data/obj.names
# !echo -e 'classes= 5\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data

# %% [markdown]
# **4) Save yolov3_training.cfg and obj.names files in Google drive**

# %%
# !cp cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_testing.cfg
# !cp data/obj.names /mydrive/yolov3/classes.txt

# %% [markdown]
# **5) Create a folder and unzip image dataset**

# %%
# !mkdir data/obj
# !unzip /mydrive/yolov3/images1.zip -d data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists
# Archive:  /mydrive/yolov3/images1.zip
# replace data/obj/images1/.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/obj/images1/.jpg
#   inflating: data/obj/images1/.jpg.txt
#   inflating: data/obj/images1/_109247571_apples1.jpg
#   inflating: data/obj/images1/_109247571_apples1.txt
#   inflating: data/obj/images1/_110697089_p06p9bdw.jpg
#   inflating: data/obj/images1/_110697089_p06p9bdw.txt
#   inflating: data/obj/images1/01_oranges_FinallyE28094HereE28099s-Which-E2809COrangeE2809D-Came-First-the-Color-or-the-Fruit_691064353_Lucky-Business-1024x683.jpg
#   inflating: data/obj/images1/01_oranges_FinallyE28094HereE28099s-Which-E2809COrangeE2809D-Came-First-the-Color-or-the-Fruit_691064353_Lucky-Business-1024x683.txt
#   inflating: data/obj/images1/03526336ef23211c5a4c91db0ff12d17.png
#   inflating: data/obj/images1/03526336ef23211c5a4c91db0ff12d17.txt
# ...

# %% [markdown]
# **6) Create train.txt file**

# %%
import glob
images_list = glob.glob("data/obj/images1/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %% [markdown]
# **7) Download pre-trained weights for the convolutional layers file**

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-12-30 20:45:45--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  9.70MB/s    in 16s
#
# 2020-12-30 20:46:01 (9.72 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %% [markdown]
# **8) Start training**

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Uncomment below and comment above to re-start your training from last saved weights
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000281, iou_loss = 0.000000, total_loss = 0.000281
#  total_bbox = 147878, rewritten_bbox = 0.362461 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.653843), count: 4, class_loss = 0.661343, iou_loss = 0.491459, total_loss = 1.152802
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000073, iou_loss = 0.000000, total_loss = 0.000073
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 147882, rewritten_bbox = 0.362451 %
# ...
